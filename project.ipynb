# %% [markdown]
# ### 1) Reading the dataset to python environment

# %%
import pandas as pd
import numpy as np
li = pd.read_csv('pjt.csv')

# %%
pd.set_option('display.max_columns', 30)
li.head(5)
# Out:
#    Unnamed: 0  ageEstimate  companyFollowerCount  \
# 0           0           41              198859.0
# 1           1           41              198859.0
# 2           2           41               10047.0
# 3           3           41              198859.0
# 4           4           30              300723.0
#
#                                companyHasLogo        companyName  \
# 0  5a92c12e-0a20-482b-95ec-e705a6294730-2.png  Commonwealth Bank
# 1  5a92c12e-0a20-482b-95ec-e705a6294730-2.png  Commonwealth Bank
# 2  b1c3fd9a-8f21-48f8-8321-d773b1ff3cb7-2.png            CommSec
# 3  5a92c12e-0a20-482b-95ec-e705a6294730-2.png  Commonwealth Bank
# 4  0f982557-a907-409e-af20-1feb0e0813cd-2.png             PayPal
#
#    companyStaffCount                   companyUrl           companyUrn  \
# 0            32905.0  http://www.commbank.com.au/  urn:li:company:2848
# 1            32905.0  http://www.commbank.com.au/  urn:li:company:2848
# ...

# %%
li.shape   #finding the number of rows and columns
# Out:
# (38679, 21)

# %% [markdown]
# The dataset consists of 38679 rows and 21 columns
#
# Each row represents an employee,detailing his/her employment and LinkedIn details

# %%
li.info() # to get an overall view about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38679 entries, 0 to 38678
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             38679 non-null  int64
#  1   ageEstimate            38679 non-null  int64
#  2   companyFollowerCount   37429 non-null  float64
#  3   companyHasLogo         35816 non-null  object
#  4   companyName            38678 non-null  object
#  5   companyStaffCount      37705 non-null  float64
#  6   companyUrl             36804 non-null  object
#  7   companyUrn             38679 non-null  object
#  8   connectionsCount       38679 non-null  int64
#  9   country                38679 non-null  object
#  10  followable             38679 non-null  int64
#  11  followersCount         38679 non-null  int64
#  12  genderEstimate         34807 non-null  object
#  13  hasPicture             28902 non-null  object
# ...

# %% [markdown]
# Missing values are present in various columns

# %%
li.describe()
# Out:
#          Unnamed: 0   ageEstimate  companyFollowerCount  companyStaffCount  \
# count  38679.000000  38679.000000          3.742900e+04       37705.000000
# mean   19763.155407     38.415342          2.178440e+05       20828.521204
# std    11416.622381      9.617105          6.995865e+05       68111.497111
# min        0.000000     20.000000          0.000000e+00           0.000000
# 25%     9850.500000     31.000000          1.666000e+03         111.000000
# 50%    19775.000000     38.000000          1.555800e+04        1396.000000
# 75%    29644.500000     45.000000          1.309520e+05        9920.000000
# max    39536.000000     86.000000          7.502740e+06      568533.000000
#
#        connectionsCount    followable  followersCount     isPremium  \
# count      38679.000000  38679.000000    38679.000000  38679.000000
# mean         424.004369      0.949844     1182.054991      0.128881
# std          123.471498      0.218270     2864.365015      0.335073
# ...

# %% [markdown]
# ### 2) Exploratory Data Analysis(EDA)

# %% [markdown]
# #### 2.1) Univariate Analysis

# %%
for i in li.columns:
    print(i,'___',li[i].nunique(),'___',li[i].dtype)
# Out:
# Unnamed: 0 ___ 38679 ___ int64
# ageEstimate ___ 59 ___ int64
# companyFollowerCount ___ 6246 ___ float64
# companyHasLogo ___ 10823 ___ object
# companyName ___ 12952 ___ object
# companyStaffCount ___ 2989 ___ float64
# companyUrl ___ 11497 ___ object
# companyUrn ___ 12979 ___ object
# connectionsCount ___ 487 ___ int64
# country ___ 1 ___ object
# followable ___ 2 ___ int64
# followersCount ___ 2192 ___ int64
# genderEstimate ___ 2 ___ object
# hasPicture ___ 4800 ___ object
# isPremium ___ 2 ___ int64
# mbrLocation ___ 472 ___ object
# posLocation ___ 5030 ___ object
# posTitle ___ 23541 ___ object
# positionId ___ 38679 ___ int64
# avgMemberPosDuration ___ 4891 ___ float64
# avgCompanyPosDuration ___ 11559 ___ float64

# %%
# importing required libraries
import numpy as np
import matplotlib.pyplot as plt # pyplot is a sublibrary in matplotlib
import seaborn as sns

# %%
plt.figure(figsize=(8,8)) 
plt.hist(li['ageEstimate'],color='Red',rwidth=0.9)
plt.title('Distribution of age',fontsize=16)
plt.xlabel('Age')  # how many times that particular MPG-Mileage appeared in our data set
plt.ylabel('Number of employees')
plt.xticks()
plt.yticks()
plt.show()

# %%
plt.boxplot(li['ageEstimate'])
plt.title('Box plot of ageEstimate')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# Age ranges from 20 to 86.Average age is 38.There are outliers present in the upper range of age feature and seems to be a natural part of the population.

# %%
li[['ageEstimate']].plot.kde() 
plt.title('Disrttibution of age')
# Out:
# Text(0.5, 1.0, 'Disrttibution of age')

# %% [markdown]
# Age feature follows a normal distribution

# %%
plt.rcParams['figure.figsize']=(6,6)
plt.pie(li['genderEstimate'].value_counts(), explode = (0, 0.05), autopct='%1.1f%%')
plt.title('Percentage of Male and Female')
plt.legend(['Male', 'Female'])
plt.show()

# %% [markdown]
# Around 67% of the respondents in the dataset are Male,whereas only 33% belong to Female category.

# %%
sns.countplot(li['companyName'],
             order=li['companyName'].value_counts().head(10).index,
             palette='dark')
plt.xticks(rotation=90)
plt.title('Top 10 companies')
# Out:
# C:\Users\param\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Top 10 companies')

# %% [markdown]
# Most of the employees in the dataset belong to Telestra,followed by National Australian Bank,Commonwealth Bank ,IBM etc.
#
# Employees from various industries are present in this dataset.

# %%
ax=sns.countplot(li['posTitle'],
             order=li['posTitle'].value_counts().head(10).index)
plt.xticks(rotation=90)
plt.title('Top 10 job roles')
# Out:
# C:\Users\param\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Top 10 job roles')

# %% [markdown]
# More than 400 employees in the dataset are working as Project Manager ,followed by Consultant and Director positions

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
plt.rcParams['figure.figsize']=(6,6)
plt.pie(li['isPremium'].value_counts(), explode = (0, 0.01), autopct='%1.1f%%')
plt.title('Percentage of Premium and non premium members')
plt.legend(['Non Premium', 'Premium'])
plt.show()

# %% [markdown]
# Among the employees, 87 % are using non premium linkedin account and the rest 13% are using Premium account

# %%
plt.figure(figsize=(8,8)) 
plt.hist(li['avgMemberPosDuration'],color='Red',rwidth=0.9)
plt.title('Distribution of avgMemberPosDuration',fontsize=16)
plt.xlabel('avgMemberPosDuration in days')  
plt.ylabel('Number of employees')
plt.xticks()
plt.yticks()
plt.show()

# %% [markdown]
# More than 90% of the employees have average member position duration between 0-1800 days.

# %%
plt.figure(figsize=(8,8)) 
plt.hist(li['avgCompanyPosDuration'],color='Blue',rwidth=0.9)
plt.title('Distribution of avgCompanyPosDuration',fontsize=16)
plt.xlabel('avgCompanyPosDuration in days')  
plt.ylabel('Number of employees')
plt.xticks()
plt.yticks()
plt.show()

# %% [raw]
# More than 90% of the employees have average company position duration between 0 to 1800 days

# %% [markdown]
# #### 2.2) Bivariate Analysis

# %%
#Age distribution with respect to gender

# %%
plt.figure(figsize=(10,5))
plt.title('Comparison among Gender based on average company position duration and average member position duration',loc='left',fontsize=16)
plt.subplot(1,2,1)
sns.boxplot(x=li['genderEstimate'],y=li['avgCompanyPosDuration'])
plt.xlabel('Gender',fontsize=12)
plt.ylabel('avgCompanyPosDuration',fontsize=12)

plt.subplot(1,2,2)
sns.boxplot(x=li['genderEstimate'],y=li['avgMemberPosDuration'])
plt.xlabel('Gender',fontsize=12)
plt.ylabel('avgMemberPosDuration',fontsize=12)

plt.tight_layout()

# %% [markdown]
# There is no substantial difference in the case of Average member position duration and average company position duration with respect to gender.

# %%
plt.figure(figsize=(5,5))
sns.countplot(data =li, x = 'isPremium', hue=li['genderEstimate'])
plt.title( "Premium and Non premium linkedIn account:Male vs Female",fontsize=16) 
plt.xlabel('Nonpremium & Premium LinkedIn account', fontsize=14)
plt.ylabel('Count',fontsize=14) 
plt.tight_layout()
plt.show()

# %% [markdown]
# Majority of Female and Male employees are having non premium LinkedIn account

# %%
sns.countplot(li['posTitle'],
             order=li['posTitle'].value_counts().head(30).index,hue=li['genderEstimate'])
plt.xticks(rotation=90)
plt.title('Gender difference among job roles')
plt.show()

# %% [markdown]
# Males are working predominantly as Project Manager,Director,Consultant
#
# Females are more oriented towards Project Mananager,Consltant,Partner roles.
#
# In Most of the job roles Male participation exceeds Female participation .
# Few of the exceptions are Research Assistant,Sales Assistant,Lawyer,Intern etc.

# %%
#Gender Vs connections count

# %%
sns.barplot(x=li['genderEstimate'],y=li['connectionsCount'],data=li)
plt.xlabel('Gender',fontsize=12)
plt.ylabel('Connections count',fontsize=12)
plt.show()

# %%
# Pair plot between selected data

# %%
slice_data=li[['avgMemberPosDuration','avgCompanyPosDuration','ageEstimate','companyStaffCount']]
sns.pairplot(slice_data)

# %%
corr_matrix=li.corr()    # Pearson standard correlation coefficient as default.    
plt.subplots(figsize=(10,10))
#using heat map for better visualisation of correlation values 
sns.heatmap(corr_matrix,vmin=-0.0089,vmax=0.5,linewidths=0.2,annot=True)      
plt.show()

# %%
#Job profile of employees working above 70 years of age

# %%
data= li.copy()

# %%
df =data.loc[data['ageEstimate']>70]

# %%
sns.countplot(df['posTitle'],order=df['posTitle'].value_counts().head(20).index)
plt.xticks(rotation=90)
plt.title('Job profile of employees working above 70 years of age')
plt.show()

# %% [markdown]
# Most of the employees above 70 years of age are working in education sector

# %%
# Top Companies where employees worked for more than 3 years
df =data.loc[data['avgCompanyPosDuration']>1095]
sns.countplot(df['companyName'],order=df['companyName'].value_counts().head(20).index)
plt.xticks(rotation=90)
plt.title('Top Companies where employees worked for more than 1095 days(3 years) ')
plt.ylabel('Number of employees',fontsize=12)
plt.show()

# %% [markdown]
# Telstra occupies the top position with respect to number of employees working  for more than 3 years,followed by IBM  and Qantas

# %%
# Top job roles in which employees worked for more than 5 years

# %%
df1 =data.loc[data['avgCompanyPosDuration']>1825]
sns.countplot(df1['posTitle'],order=df1['posTitle'].value_counts().head(3).index)
plt.xticks(rotation=90)
plt.title('Top job roles in which employees worked for more than 1825 days(5 years) ')
plt.ylabel('Number of employees',fontsize=12)
plt.show()

# %% [markdown]
# The top three job profiles in which highest number of employees worked for more than 5 years are Director,Managing director,and Army office roles.

# %% [markdown]
# ### 3)  Preprocessing the dataset

# %% [markdown]
# #### 3.1) Missing value handling

# %%
# Checking for missing values
li.isna().sum()
# Out:
# Unnamed: 0                   0
# ageEstimate                  0
# companyFollowerCount      1250
# companyHasLogo            2863
# companyName                  1
# companyStaffCount          974
# companyUrl                1875
# companyUrn                   0
# connectionsCount             0
# country                      0
# followable                   0
# followersCount               0
# genderEstimate            3872
# hasPicture                9777
# isPremium                    0
# mbrLocation                  0
# posLocation              11005
# posTitle                     0
# positionId                   0
# avgMemberPosDuration       207
# avgCompanyPosDuration        0
# dtype: int64

# %% [markdown]
# Missing values are present in companyFollowerCount,companyHasLogo,companyName,companyStaffCount,companyUrl,genderEstimate,hasPicture ,posLocation,
# avgMemberPosDuration

# %%
#Filling company follower count.
# For a particular company,Follower count will be the same in every row.There is one missing value in companyName
#where as companyUrn doesnt have any null values
# So using group by companyUrn and median to fill the value

# %%
li['companyFollowerCount'] = li['companyFollowerCount'].fillna(li.groupby('companyName')['companyFollowerCount'].transform('median'))

# %%
#Filling the rest with median of 'companyFollowerCount' column
li['companyFollowerCount']=li['companyFollowerCount'].fillna(li['companyFollowerCount'].median())

# %%
#Filling the missing values in 'companyHasLogo'column using group by companyName and mode

# %%
g = lambda x: x.fillna(x.mode().iat[0]) if x.notna().any() else x
li['companyHasLogo'] = li.groupby('companyName')['companyHasLogo'].apply(g)

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# %%
li.isna().sum()
# Out:
# Unnamed: 0                   0
# ageEstimate                  0
# companyFollowerCount         0
# companyHasLogo            2832
# companyName                  1
# companyStaffCount          974
# companyUrl                1875
# companyUrn                   0
# connectionsCount             0
# country                      0
# followable                   0
# followersCount               0
# genderEstimate            3872
# hasPicture                9777
# isPremium                    0
# mbrLocation                  0
# posLocation              11005
# posTitle                     0
# positionId                   0
# avgMemberPosDuration       207
# avgCompanyPosDuration        0
# dtype: int64

# %%
li[li['companyHasLogo'].isnull()]
# Out:
#        Unnamed: 0  ageEstimate  companyFollowerCount companyHasLogo  \
# 82             83           44                  25.0            NaN
# 126           127           36               15556.0            NaN
# 146           147           47                3290.0            NaN
# 155           157           30                3118.0            NaN
# 178           180           43               15556.0            NaN
# ...           ...          ...                   ...            ...
# 38633       39491           41               15556.0            NaN
# 38639       39497           45                 138.0            NaN
# 38661       39519           42                 638.0            NaN
# 38668       39526           29                 629.0            NaN
# 38669       39527           29                 629.0            NaN
#
#                                            companyName  companyStaffCount  \
# 82                          Burgess Hill Physiotherapy                1.0
# ...

# %%
li.loc[li['companyName'] == 'EDAW']
# Out:
#        Unnamed: 0  ageEstimate  companyFollowerCount companyHasLogo  \
# 146           147           47                3290.0            NaN
# 13126       13413           49                3290.0            NaN
# 13127       13414           49                3290.0            NaN
#
#       companyName  companyStaffCount            companyUrl  \
# 146          EDAW              309.0  http://www.aecom.com
# 13126        EDAW              309.0  http://www.aecom.com
# 13127        EDAW              309.0  http://www.aecom.com
#
#                  companyUrn  connectionsCount country  followable  \
# 146    urn:li:company:10384               500      au           1
# 13126  urn:li:company:10384               500      au           1
# 13127  urn:li:company:10384               500      au           1
#
#        followersCount genderEstimate  \
# 146              1191           male
# 13126            1682           male
# 13127            1682           male
#
# ...

# %% [markdown]
# Dividing the data frame into 2 sections(for explanation purpose),one in which no missing value present and two consisting of all rows where atleast one missing value present
# Nothing in 'companyHasLogo' got filled because of one reason :the company url appeared only in section 2

# %%
#So filling the rest of missing values in 'companyHasLogo' with 'Unknown'tag
li['companyHasLogo'] = li['companyHasLogo'].fillna('unknown')

# %%
# Only one value is missing in the company Name column
# Finding the row where Company name is Null

# %%
li[li['companyName'].isnull()]
# Out:
#        Unnamed: 0  ageEstimate  companyFollowerCount companyHasLogo  \
# 18805       19225           32               15556.0        unknown
#
#       companyName  companyStaffCount companyUrl               companyUrn  \
# 18805         NaN                NaN        NaN  urn:li:company:18392788
#
#        connectionsCount country  followable  followersCount genderEstimate  \
# 18805               198      au           1             198           male
#
#                                             hasPicture  isPremium  \
# 18805  YG0bPgUbBZP_-GFdDztJxrfULf_MoU7RvWk38lsqo4k.jpg          0
#
#              mbrLocation        posLocation                      posTitle  \
# 18805  Sydney, Australia  Sydney, Australia  Digital Marketing Specialist
#
#        positionId  avgMemberPosDuration  avgCompanyPosDuration
# 18805      176511                 562.6                 745.25

# %%
#Checking is there is any other row where companyUrn is same

# %%
li.loc[li['companyUrn'] == 'urn:li:company:18392788']
# Out:
#        Unnamed: 0  ageEstimate  companyFollowerCount companyHasLogo  \
# 18805       19225           32               15556.0        unknown
#
#       companyName  companyStaffCount companyUrl               companyUrn  \
# 18805         NaN                NaN        NaN  urn:li:company:18392788
#
#        connectionsCount country  followable  followersCount genderEstimate  \
# 18805               198      au           1             198           male
#
#                                             hasPicture  isPremium  \
# 18805  YG0bPgUbBZP_-GFdDztJxrfULf_MoU7RvWk38lsqo4k.jpg          0
#
#              mbrLocation        posLocation                      posTitle  \
# 18805  Sydney, Australia  Sydney, Australia  Digital Marketing Specialist
#
#        positionId  avgMemberPosDuration  avgCompanyPosDuration
# 18805      176511                 562.6                 745.25

# %%
#Only one row with this specific companyUrn and is the same we need to fill.
#So dropping the row.
li = li.dropna(axis=0, subset=['companyName'])

# %%
# Filling missing values in companyStaffCount
# Grouping by companyName and median to fill the value

# %%
li['companyStaffCount'] = li['companyStaffCount'].fillna(li.groupby('companyName')['companyStaffCount'].transform('median'))

# %%
#Filling the rest with median of the company staff count column

# %%
li['companyStaffCount']=li['companyStaffCount'].fillna(li['companyStaffCount'].median())

# %%
#Filling company url 
# Grouping by companyName and mode to fill the value

# %%
g = lambda x: x.fillna(x.mode().iat[0]) if x.notna().any() else x
li['companyUrl'] = li.groupby('companyName')['companyUrl'].apply(g)

# %%
#Filling the rest  of missing values in 'companyUrl' by 'Unknown' tag
li['companyUrl'] = li['companyUrl'].fillna('unknown')

# %%
#Filling values in GenderEstimate column
# Grouping by companyName and mode to fill the value

# %%
f = lambda x: x.fillna(x.mode().iat[0]) if x.notna().any() else x
li['genderEstimate'] = li.groupby('companyUrn')['genderEstimate'].apply(f)

# %%
li['genderEstimate'].isna().sum()
# Out:
# 1238

# %%
#filling the rest with maximum occuring value in the column
li['genderEstimate']=li['genderEstimate'].fillna(li['genderEstimate'].mode()[0])

# %%
#Filling the missing values in 'hasPicture' column with 'No' tag
li['hasPicture'] = li['hasPicture'].fillna('No')

# %%
#Filling the missing values in posLocation by Grouping with companyName and Mode

# %%
g = lambda x: x.fillna(x.mode().iat[0]) if x.notna().any() else x
li['posLocation'] = li.groupby('companyName')['posLocation'].apply(g)

# %%
##Filling the rest with median of the posLocation column  
li['posLocation']=li['posLocation'].fillna(li['posLocation'].mode()[0])

# %%
#Filling the missing value in avgMemberPosDuration using groupby posTitle and Median

# %%
li['avgMemberPosDuration'] = li['avgMemberPosDuration'].fillna(li.groupby('posTitle')['avgMemberPosDuration'].transform('median'))

# %%
#Filling the rest with median of avgMemberPosDuration column
li['avgMemberPosDuration']=li['avgMemberPosDuration'].fillna(li['avgMemberPosDuration'].median())

# %%
li.isna().sum()
# Out:
# Unnamed: 0               0
# ageEstimate              0
# companyFollowerCount     0
# companyHasLogo           0
# companyName              0
# companyStaffCount        0
# companyUrl               0
# companyUrn               0
# connectionsCount         0
# country                  0
# followable               0
# followersCount           0
# genderEstimate           0
# hasPicture               0
# isPremium                0
# mbrLocation              0
# posLocation              0
# posTitle                 0
# positionId               0
# avgMemberPosDuration     0
# avgCompanyPosDuration    0
# dtype: int64

# %% [markdown]
# #### 3.2)  Outlier detection and handling

# %%
for i in li.columns:
    print(i,'___',li[i].nunique(),'___',li[i].dtype)
# Out:
# Unnamed: 0 ___ 38678 ___ int64
# ageEstimate ___ 59 ___ int64
# companyFollowerCount ___ 6248 ___ float64
# companyHasLogo ___ 10824 ___ object
# companyName ___ 12952 ___ object
# companyStaffCount ___ 2991 ___ float64
# companyUrl ___ 11498 ___ object
# companyUrn ___ 12978 ___ object
# connectionsCount ___ 487 ___ int64
# country ___ 1 ___ object
# followable ___ 2 ___ int64
# followersCount ___ 2192 ___ int64
# genderEstimate ___ 2 ___ object
# hasPicture ___ 4801 ___ object
# isPremium ___ 2 ___ int64
# mbrLocation ___ 472 ___ object
# posLocation ___ 5030 ___ object
# posTitle ___ 23541 ___ object
# positionId ___ 38678 ___ int64
# avgMemberPosDuration ___ 4914 ___ float64
# avgCompanyPosDuration ___ 11559 ___ float64

# %%
# Using Box plot to determine outliers in continuous numeric variables
# Avoiding Unnamed: 0,followable,positionId
# Avoiding companyFollowerCount,connectionsCount,followersCout which doesn't require any outlier detection

# %%
a = 3  # number of rows
b = 3  # number of columns
c = 1  # initialize plot counter

fig = plt.figure(figsize=(15,10))

for i in 'ageEstimate','companyStaffCount','avgMemberPosDuration','avgCompanyPosDuration':
    plt.subplot(a, b, c)
    #plt.title('{}'.format(i),fontsize=20)
    li.boxplot([i])
    c = c + 1

plt.tight_layout()
plt.show()

# %%
# Finding the outlier in ageEstimate using percentiles
import numpy as np
Q1=np.percentile(li['ageEstimate'],25,interpolation='midpoint')
Q2=np.percentile(li['ageEstimate'],50,interpolation='midpoint')
Q3=np.percentile(li['ageEstimate'],75,interpolation='midpoint')
IQR=Q3-Q1
low_limit=Q1-1.5*IQR
Up_limit=Q3+1.5*IQR
outlier=[]
for x in li['ageEstimate']:
    if((x>Up_limit) or (x<low_limit)):
       outlier.append(x)
print('Number of outliers',len(outlier))
# Out:
# Number of outliers 129

# %%
outlier
# Out:
# [72,
#  72,
#  72,
#  74,
#  69,
#  69,
#  69,
#  69,
#  69,
#  69,
#  69,
#  69,
#  70,
#  70,
#  70,
#  70,
#  70,
#  67,
#  67,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  70,
#  67,
#  67,
#  67,
#  72,
#  72,
#  72,
#  73,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  67,
#  67,
#  71,
#  68,
#  68,
#  68,
#  68,
#  67,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  76,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  69,
#  69,
#  82,
#  70,
#  70,
#  75,
#  75,
#  69,
#  69,
#  69,
#  69,
#  69,
#  69,
#  69,
#  69,
#  69,
#  69,
#  69,
#  68,
#  68,
#  68,
#  72,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  73,
#  70,
#  70]

# %% [markdown]
# Age above 67(only 0.33 % of total set of values) are considered as outliers,but it can be considered as a part of the natural poulation.So leaving it in the dataset

# %%
# Finding the outlier in companyStaffCount using percentiles
import numpy as np
Q1=np.percentile(li['companyStaffCount'],25,interpolation='midpoint')
Q2=np.percentile(li['companyStaffCount'],50,interpolation='midpoint')
Q3=np.percentile(li['companyStaffCount'],75,interpolation='midpoint')
IQR=Q3-Q1
low_limit=Q1-1.5*IQR
Up_limit=Q3+1.5*IQR
outlier=[]
for x in li['companyStaffCount']:
    if((x>Up_limit) or (x<low_limit)):
       outlier.append(x)
print('Number of outliers',len(outlier))
# Out:
# Number of outliers 5918

# %%
outlier
# Out:
# [32905.0,
#  32905.0,
#  32905.0,
#  568533.0,
#  568533.0,
#  568533.0,
#  568533.0,
#  568533.0,
#  568533.0,
#  160863.0,
#  121437.0,
#  91629.0,
#  118819.0,
#  235683.0,
#  27944.0,
#  32905.0,
#  180604.0,
#  258692.0,
#  140424.0,
#  142211.0,
#  142211.0,
#  36243.0,
#  77961.0,
#  43616.0,
#  36243.0,
#  36243.0,
#  36243.0,
#  36243.0,
#  36243.0,
#  36243.0,
#  36243.0,
#  36243.0,
#  40515.0,
#  40515.0,
#  27944.0,
#  27944.0,
#  61388.0,
#  60800.0,
#  43616.0,
#  70181.0,
#  44769.0,
#  32547.0,
#  32547.0,
#  32547.0,
#  32547.0,
#  61458.0,
#  24953.0,
#  223507.0,
#  235683.0,
#  27603.0,
#  36243.0,
#  30337.0,
#  29919.0,
#  29919.0,
#  29919.0,
#  28398.0,
#  28398.0,
#  28398.0,
#  28398.0,
#  60800.0,
#  43616.0,
#  118819.0,
#  277621.0,
#  118819.0,
#  142211.0,
#  142211.0,
#  142211.0,
#  142211.0,
#  377002.0,
#  27944.0,
#  73474.0,
#  129610.0,
#  61388.0,
#  61388.0,
#  61388.0,
#  61388.0,
#  40515.0,
#  40515.0,
#  40515.0,
#  40515.0,
#  56217.0,
# ...

# %%
Q3+1.5*IQR
# Out:
# 23649.0

# %% [markdown]
# Staff count above 23649 are considered as outliers.
#
# The dataset consist of companies of varying sizes and its natural for large multinational companies to have staff strength greater than 23649,So leaving the outlier as it is.

# %%
# Finding the outlier in avgMemberPosDuration using percentiles
import numpy as np
Q1=np.percentile(li['avgMemberPosDuration'],25,interpolation='midpoint')
Q2=np.percentile(li['avgMemberPosDuration'],50,interpolation='midpoint')
Q3=np.percentile(li['avgMemberPosDuration'],75,interpolation='midpoint')
IQR=Q3-Q1
low_limit=Q1-1.5*IQR
Up_limit=Q3+1.5*IQR
outlier=[]
for x in li['avgMemberPosDuration']:
    if((x>Up_limit) or (x<low_limit)):
       outlier.append(x)
print('Number of outliers',len(outlier))
# Out:
# Number of outliers 1878

# %%
outlier
# Out:
# [2287.8333,
#  2287.8333,
#  3439.2,
#  3439.2,
#  3439.2,
#  3439.2,
#  3439.2,
#  3256.0,
#  3256.0,
#  2983.0,
#  2739.3333,
#  2739.3333,
#  2739.3333,
#  2518.5,
#  2518.5,
#  2518.5,
#  2070.0,
#  2802.0,
#  2802.0,
#  2282.0,
#  2282.0,
#  2282.0,
#  2282.0,
#  2891.0,
#  2891.0,
#  2891.0,
#  2016.75,
#  2016.75,
#  2016.75,
#  2016.75,
#  3089.0,
#  3089.0,
#  3089.0,
#  2721.0,
#  2721.0,
#  2721.0,
#  2549.0,
#  2549.0,
#  2549.0,
#  2549.0,
#  2549.0,
#  1924.75,
#  1924.75,
#  1924.75,
#  1924.75,
#  3867.0,
#  3867.0,
#  3867.0,
#  4991.0,
#  4991.0,
#  4991.0,
#  4991.0,
#  2525.0,
#  2004.0,
#  2004.0,
#  2004.0,
#  2004.0,
#  2702.2,
#  2702.2,
#  2702.2,
#  2702.2,
#  2702.2,
#  2876.3333,
#  2876.3333,
#  2876.3333,
#  2099.3333,
#  2099.3333,
#  2191.0,
#  1927.0,
#  1927.0,
#  3105.0,
#  3105.0,
#  3105.0,
#  3105.0,
#  2161.0,
#  2161.0,
#  2038.0,
#  2038.0,
#  2170.8333,
#  2170.8333,
#  2170.8333,
#  2170.8333,
#  2170.8333,
#  2170.8333,
#  2170.8333,
# ...

# %%
Q3+1.5*IQR
# Out:
# 1909.37505

# %% [markdown]
# The column 'avgMemberPosDuration' denotes the average number of days an employee serves in a particular job role.Here values above 1909 (5 years) are treated as outliers.
#
# But avgMemberPosDuration> 5 years is possible,especially in education sector,and in assistant job roles(where the employee have only the minimum qualifiation and remains in the same position during the entire career span),also when employees are avoiding promotions and remains only in their comfortable job roles(especially in banks)
#
# So leaving the outlier as it is.

# %%
# Finding the outlier in avgCompanyPosDuration using percentiles
Q1=np.percentile(li['avgCompanyPosDuration'],25,interpolation='midpoint')
Q2=np.percentile(li['avgCompanyPosDuration'],50,interpolation='midpoint')
Q3=np.percentile(li['avgCompanyPosDuration'],75,interpolation='midpoint')
IQR=Q3-Q1
low_limit=Q1-1.5*IQR
Up_limit=Q3+1.5*IQR
outlier=[]
for x in li['avgCompanyPosDuration']:
    if((x>Up_limit) or (x<low_limit)):
       outlier.append(x)
print('Number of outliers',len(outlier))
# Out:
# Number of outliers 1868

# %%
outlier
# Out:
# [185.8841,
#  1598.0,
#  146.6,
#  3803.0,
#  1513.8837,
#  1513.8837,
#  1513.8837,
#  1535.3333,
#  1535.3,
#  1535.3,
#  3591.0,
#  244.0,
#  214.0,
#  2051.3,
#  214.0,
#  1520.3188,
#  1552.0714,
#  212.0,
#  181.0,
#  182.0,
#  182.0,
#  213.6667,
#  213.6667,
#  2187.4245,
#  1838.2857,
#  2326.6061,
#  183.0,
#  1794.0,
#  1740.0909,
#  2153.949,
#  1826.0,
#  101.3333,
#  3622.0,
#  1544.5,
#  240.1667,
#  240.1667,
#  114.5217,
#  114.5217,
#  114.5217,
#  114.5217,
#  1805.0,
#  202.3333,
#  2607.2,
#  1552.0,
#  184.0,
#  144.0472,
#  167.0,
#  153.0,
#  1765.0,
#  1765.0,
#  2187.4245,
#  2282.0,
#  219.8,
#  243.3125,
#  239.25,
#  2326.6061,
#  1569.0,
#  2187.4245,
#  2260.269,
#  2099.0,
#  1619.7368,
#  1614.6829,
#  214.0,
#  1733.7059,
#  122.0,
#  61.0,
#  227.5,
#  28.0,
#  190.25,
#  1523.0,
#  1697.1333,
#  1613.0,
#  1569.4737,
#  1569.4737,
#  1569.4737,
#  60.0,
#  2221.0,
#  1543.2857,
#  242.0,
#  1529.7143,
#  1688.1579,
#  157.1667,
#  172.3333,
# ...

# %%
Q3+1.5*IQR
# Out:
# 1510.31815

# %% [markdown]
# The column 'avgCompanyPosDuration' denotes the average number of days an employee serves an organisation in a particular job role.Here values above 1909 (5 years) are treated as outliers.But it's quite possible for an employee to serve a company in particular job role for years.So leaving the outliers as it is.

# %%
c=li.copy()

# %%
#Doing feature engineering w.r.t mbrLocation,posLocation before encoding .

# %%
# From the place description,taking only first two elements.(preferably place/street and area/country)

# %%
li['mbrLocation'] = li['mbrLocation'].str.split(',').apply(lambda x: x[0:2])
li['posLocation'] = li['posLocation'].str.split(',').apply(lambda x: x[0:2])

# %%
col='companyName'    
print(col, li[col].str.len().ne(li[col].str.encode("ascii", errors="ignore").str.len()).sum())
# Out:
# companyName 336

# %%
pd.set_option('display.max_rows', 500)
li[li["companyName"].str.len().ne(li["companyName"].str.encode("ascii", errors="ignore").str.len())==True]
# Out:
#        Unnamed: 0  ageEstimate  companyFollowerCount  \
# 32             32           42             3081546.0
# 316           323           39               81613.0
# 322           329           53                1295.0
# 483           495           40              372183.0
# 485           497           40              372183.0
# 548           560           40               81613.0
# 549           561           40               81613.0
# 550           562           40               81613.0
# 754           772           33              372183.0
# 836           855           48               12364.0
# 1299         1327           28                1055.0
# 1300         1328           28                1055.0
# 1301         1329           28                1055.0
# 1303         1331           28                1055.0
# 1648         1679           35               81613.0
# 1982         2017           36              498475.0
# 1983         2018           36              498475.0
# ...

# %%
# Non-ASCII characters are present in the data frame.

# %%
# Removing those Non-ASCII characters from relevent column

# %%
import unicodedata
li['companyName'] = li['companyName'].apply(lambda val: unicodedata.normalize('NFKD', val).encode('ascii', 'ignore').decode())

# %%
#'companyName' in one column still not correct,so extracting the name from companyUrl

# %%
 li['companyName'].loc[4586]=li['companyUrl'].loc[4586].split("www.")[-1].split("//")[-1].split(".")[0]

# %%
#Also dropping a row where the 'companyName 'is just a number and no other matching details available in the data set.

# %%
li.drop(li[li['companyName'] =='4399'].index,inplace = True)

# %%
# In two rows,'posLocation' was given as '4300' which needs to be replaced by 'Brisbane, Australia'

# %%
li[li['companyName'] =='Shape Consulting']
# Out:
#        Unnamed: 0  ageEstimate  companyFollowerCount  \
# 27923       28534           26                 465.0
# 27928       28539           26                 465.0
# 37155       37990           58                 465.0
#
#                                    companyHasLogo       companyName  \
# 27923  b41eeb6b-4735-453b-94a8-c1dce377ccdc-2.png  Shape Consulting
# 27928  b41eeb6b-4735-453b-94a8-c1dce377ccdc-2.png  Shape Consulting
# 37155  b41eeb6b-4735-453b-94a8-c1dce377ccdc-2.png  Shape Consulting
#
#        companyStaffCount                         companyUrl  \
# 27923               17.0  http://www.shapeconsulting.com.au
# 27928               17.0  http://www.shapeconsulting.com.au
# 37155               17.0  http://www.shapeconsulting.com.au
#
#                   companyUrn  connectionsCount country  followable  \
# 27923  urn:li:company:269391               125      au           1
# 27928  urn:li:company:269391               125      au           1
# ...

# %%
li['posLocation'] = li['posLocation'].replace(['4300'],['Brisbane, Australia'])

# %%
# mbrLocation,posLocation are stored as list,so delisting and converting to string

# %%
li['posLocation'] = li['posLocation'].astype(str).apply(eval).apply(' '.join)

# %%
li['mbrLocation'] = li['mbrLocation'].astype(str).apply(eval).apply(' '.join)

# %%
li[li['posLocation'] =='.']
# Out:
#        Unnamed: 0  ageEstimate  companyFollowerCount  \
# 22970       23492           40               15556.0
# 35324       36102           38                1224.0
# 35325       36103           38                 936.0
# 35326       36104           38                 437.0
#
#                                    companyHasLogo           companyName  \
# 22970                                     unknown  Seeking New Position
# 35324  c3705a6a-0668-45ba-bbc2-0512be4e3908-2.png    Knowledge Platform
# 35325  9fce2019-3679-4e94-8986-10c5fc74f730-2.png  Ikonami Technologies
# 35326  41858068-1ea5-4a61-bfb5-d430f351d0dc-2.png             TEKenable
#
#        companyStaffCount                        companyUrl  \
# 22970             1396.0                           unknown
# 35324               97.0  http://www.knowledgeplatform.com
# 35325               36.0               http://ikonami.com/
# 35326               37.0          http://www.tekenable.com
#
# ...

# %%
# #Need to delete the row at index no :22970 ,where the companyName is just a random sentence
li.drop(li[li['companyName'] =='Seeking New Position'].index,inplace = True)

# %%
#Filling the 'posLocation' in other three rows using general mode(Since no matching company details are available)
li['posLocation'] = li['posLocation'].replace('.',li['posLocation'].mode()[0])

# %%
li.iloc[[13206]]
# Out:
#        Unnamed: 0  ageEstimate  companyFollowerCount  \
# 13206       13493           46               81613.0
#
#                                    companyHasLogo      companyName  \
# 13206  a67c4138-4f24-4932-8343-8c852a32dd55-2.png  nbnTM Australia
#
#        companyStaffCount             companyUrl             companyUrn  \
# 13206             5972.0  http://www.nbn.com.au  urn:li:company:638710
#
#        connectionsCount country  followable  followersCount genderEstimate  \
# 13206               500      au           1            1415           male
#
#                                             hasPicture  isPremium  \
# 13206  cZBYlIdbbACfrCvZ3-sg11-YQPXe_6LMXxYYXHo6GGI.jpg          0
#
#                 mbrLocation  \
# 13206  Melbourne  Australia
#
#                                              posLocation  \
# 13206  ~35 000 Km above the equator in geosynchronous...
#
#                                                 posTitle  positionId  \
# ...

# %%
#random text in posLocation,so 'posLocation' can be replaced using grouping by companyName and Mode.

# %%
li.at[13206,'posLocation']= li['posLocation'].mode()[0]

# %%
li[li['companyName'] =='nbnTM Australia']
# Out:
#        Unnamed: 0  ageEstimate  companyFollowerCount  \
# 316           323           39               81613.0
# 548           560           40               81613.0
# 549           561           40               81613.0
# 550           562           40               81613.0
# 1648         1679           35               81613.0
# 2408         2451           25               81613.0
# 2784         2837           48               81613.0
# 2790         2843           48               81613.0
# 4820         4925           52               81613.0
# 6682         6823           40               81613.0
# 6965         7110           38               81613.0
# 6967         7112           38               81613.0
# 7833         7991           42               81613.0
# 7834         7992           42               81613.0
# 8367         8533           35               81613.0
# 8689         8858           59               81613.0
# 10030       10221           38               81613.0
# ...

# %%
li.columns
# Out:
# Index(['Unnamed: 0', 'ageEstimate', 'companyFollowerCount', 'companyHasLogo',
#        'companyName', 'companyStaffCount', 'companyUrl', 'companyUrn',
#        'connectionsCount', 'country', 'followable', 'followersCount',
#        'genderEstimate', 'hasPicture', 'isPremium', 'mbrLocation',
#        'posLocation', 'posTitle', 'positionId', 'avgMemberPosDuration',
#        'avgCompanyPosDuration'],
#       dtype='object')

# %% [markdown]
# #### 3.3)  Encoding

# %%
#Encoding the categorical variables using label encoder

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
for i in li.columns:
    if li[i].dtype == 'object':
        li[i]= label_encoder.fit_transform(li[i].astype(str))

# %%
li.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38676 entries, 0 to 38678
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             38676 non-null  int64
#  1   ageEstimate            38676 non-null  int64
#  2   companyFollowerCount   38676 non-null  float64
#  3   companyHasLogo         38676 non-null  int32
#  4   companyName            38676 non-null  int32
#  5   companyStaffCount      38676 non-null  float64
#  6   companyUrl             38676 non-null  int32
#  7   companyUrn             38676 non-null  int32
#  8   connectionsCount       38676 non-null  int64
#  9   country                38676 non-null  int32
#  10  followable             38676 non-null  int64
#  11  followersCount         38676 non-null  int64
#  12  genderEstimate         38676 non-null  int32
#  13  hasPicture             38676 non-null  int32
# ...

# %% [markdown]
# #### 3.4) Feature reduction

# %% [markdown]
# Dropping 'Unnamed: 0 ',since it's representing only an additional index

# %%
li.drop(['Unnamed: 0'],axis=1,inplace=True)
c.drop(['Unnamed: 0'],axis=1,inplace=True) # copied dataframe for correlation matrix

# %%
li.columns
# Out:
# Index(['ageEstimate', 'companyFollowerCount', 'companyHasLogo', 'companyName',
#        'companyStaffCount', 'companyUrl', 'companyUrn', 'connectionsCount',
#        'country', 'followable', 'followersCount', 'genderEstimate',
#        'hasPicture', 'isPremium', 'mbrLocation', 'posLocation', 'posTitle',
#        'positionId', 'avgMemberPosDuration', 'avgCompanyPosDuration'],
#       dtype='object')

# %% [markdown]
# ##### 3.4.1) Reducing categorical columns

# %%
#From 'companyName','companyUrl','companyUrn' selecting companyName as the representative feature
#Checking whether companyName have a significant effect on avgCompanyPosDuration using ANOVA test
# Null hypothesis(H0): 'companyName' doesnt have a significant effect on avgCompanyPosDuration

# %%
from scipy.stats import f_oneway
CategoryGroupLists=li.groupby('companyName')['avgCompanyPosDuration'].apply(list)
AnovaResults = f_oneway(*CategoryGroupLists)
print('P-Value for Anova is:', AnovaResults[1])
# Out:
# P-Value for Anova is: 0.0

# %%
# Since the p value is less than the selected significance level of 0.05 ,rejecting the null hypothesis 
# So companyName' have a significant effect on avgCompanyPosDuration.

# %%
# As 'companyName' is the representative feature,dropping companyUrl' and 'companyUrn' from the data set

# %%
# The features'companyHasLogo','hasPicture' directs to image files of company and employee respectively.
# So,dropping these two columns as well

# %%
#The'country' feature has only one value and so it's not contributing to model.So dropping the column

# %%
#Position id of each employee is a unique value and is not contributing to the model.So dropping the column

# %%
#Checking whether 'followable' status have a significant effect on avgCompanyPosDuration using ANOVA test
# Null hypothesis(H0): 'followable' doesnt have a significant effect on avgCompanyPosDuration

# %%
from scipy.stats import f_oneway
CategoryGroupLists=li.groupby('followable')['avgCompanyPosDuration'].apply(list)
AnovaResults = f_oneway(*CategoryGroupLists)
print('P-Value for Anova is:', AnovaResults[1])
# Out:
# P-Value for Anova is: 0.3794809633018533

# %%
# Since the p value is greater than the selected significance level of 0.05 ,failing to reject the null hypothesis 
# So 'followable' doesn't have a significant effect on avgCompanyPosDuration.
#Therefore dropping 'followable' column

# %%
#Checking whether 'genderEstimate' have a significant effect on avgCompanyPosDuration using ANOVA test
# Null hypothesis(H0): 'genderEstimate' doesnt have a significant effect on avgCompanyPosDuration

# %%
from scipy.stats import f_oneway
CategoryGroupLists=li.groupby('genderEstimate')['avgCompanyPosDuration'].apply(list)
AnovaResults = f_oneway(*CategoryGroupLists)
print('P-Value for Anova is:',AnovaResults[1])
# Out:
# P-Value for Anova is: 2.4932726660424402e-11

# %%
# Since the p value is less than the selected significance level of 0.05 ,rejecting the null hypothesis 
# So 'genderEstimate' have a significant effect on avgCompanyPosDuration.

# %%
#Checking whether 'isPremium' (profile premium/ordinary) have a significant effect on avgCompanyPosDuration using ANOVA test
# Null hypothesis(H0): 'isPremium' doesnt have a significant effect on avgCompanyPosDuration

# %%
from scipy.stats import f_oneway
CategoryGroupLists=li.groupby('isPremium')['avgCompanyPosDuration'].apply(list)
AnovaResults = f_oneway(*CategoryGroupLists)
print('P-Value for Anova is:',AnovaResults[1])
# Out:
# P-Value for Anova is: 0.07759167417129827

# %%
# Since the p value is greater than the selected significance level of 0.05 ,failing to reject the null hypothesis 
# So 'isPremium' doesn't have a significant effect on avgCompanyPosDuration.
#Therefore dropping 'isPremium' column

# %%
#Checking whether 'mbrLocation' (Employee Location) have a significant effect on avgCompanyPosDuration using ANOVA test
# Null hypothesis(H0): 'mbrLocation' doesnt have a significant effect on avgCompanyPosDuration

# %%
from scipy.stats import f_oneway
CategoryGroupLists=li.groupby('mbrLocation')['avgCompanyPosDuration'].apply(list)
AnovaResults = f_oneway(*CategoryGroupLists)
print('P-Value for Anova is:', AnovaResults[1])
# Out:
# P-Value for Anova is: 2.1875891290361225e-106

# %%
# Since the p value is less than the selected significance level of 0.05 ,rejecting the null hypothesis 
# So 'mbrLocation' have a significant effect on avgCompanyPosDuration.

# %%
#Checking whether 'posLocation' (Company/Institution Location) have a significant effect on avgCompanyPosDuration using ANOVA test
# Null hypothesis(H0): 'posLocation' doesnt have a significant effect on avgCompanyPosDuration

# %%
from scipy.stats import f_oneway
CategoryGroupLists=li.groupby('posLocation')['avgCompanyPosDuration'].apply(list)
AnovaResults = f_oneway(*CategoryGroupLists)
print('P-Value for Anova is:', AnovaResults[1])
# Out:
# P-Value for Anova is: 5.940386601249564e-222

# %%
# Since the p value is less than the selected significance level of 0.05 ,rejecting the null hypothesis 
# So 'posLocation' have a significant effect on avgCompanyPosDuration.

# %%
#Checking whether 'posTitle' have a significant effect on avgCompanyPosDuration using ANOVA test
# Null hypothesis(H0): 'posTitle' doesnt have a significant effect on avgCompanyPosDuration

# %%
from scipy.stats import f_oneway
CategoryGroupLists=li.groupby('posTitle')['avgCompanyPosDuration'].apply(list)
AnovaResults = f_oneway(*CategoryGroupLists)
print('P-Value for Anova is:', AnovaResults[1])
# Out:
# P-Value for Anova is: 2.63483756270635e-47

# %%
# Since the p value is less than the selected significance level of 0.05 ,rejecting the null hypothesis 
# So 'posTitle' have a significant effect on avgCompanyPosDuration.

# %%
#Dropping the irrelevant categorical columns
li.drop(['companyUrl','companyUrn','companyHasLogo','hasPicture','country','followable','isPremium','positionId'],axis=1,inplace=True)
c.drop(['followable','isPremium','positionId','posLocation'],axis=1,inplace=True)

# %% [markdown]
# ##### 3.4.2) Reducing continuous numerical columns

# %%
#Finding the correlation between continuous numerical variables

# %%
corr_matrix=round(c.corr(),2)    # Pearson standard correlation coefficient as default.    
plt.subplots(figsize=(5,5))
#using heat map for better visualisation of correlation values 
sns.heatmap(corr_matrix,vmin=-0.0089,vmax=0.5,linewidths=0.2,annot=True)      
plt.show()

# %%
#Taking only those columns which have correlation factor>0.1 with the target variable
#Only age estimate and avgMemberPosDuration fit to the criteria.
# age estimate and avgMemberPosDuration are correlated with a correlation factor of 0.4
#So taking only the age estimate and companyStaffCount,dropping all other columns among these

# %%
li.drop(['connectionsCount','followersCount','companyFollowerCount','avgMemberPosDuration'],axis=1,inplace=True)

# %%
li.columns
# Out:
# Index(['ageEstimate', 'companyName', 'companyStaffCount', 'genderEstimate',
#        'mbrLocation', 'posLocation', 'posTitle', 'avgCompanyPosDuration'],
#       dtype='object')

# %%
# added back company staff count

# %% [markdown]
# #### 3.5) Standard Scaling

# %% [markdown]
# Applying standard scaling to continuous numerical column 'ageEstimate' among the features,others are encoded/true categorical columns

# %%
from sklearn import preprocessing
standardisation=preprocessing.StandardScaler()
li[['ageEstimate']]=standardisation.fit_transform(li[['ageEstimate']])
li[['companyStaffCount']]=standardisation.fit_transform(li[['companyStaffCount']])

# %% [markdown]
# #### 3.6) Feature Engineering

# %%
#Converting values in avgCompanyPosDuration from days to years
li['avgCompanyPosDuration']=round((li['avgCompanyPosDuration'])/365,2)

# %%
#After preprocessing remaining columns in the data set:
li.columns
# Out:
# Index(['ageEstimate', 'companyName', 'companyStaffCount', 'genderEstimate',
#        'mbrLocation', 'posLocation', 'posTitle', 'avgCompanyPosDuration'],
#       dtype='object')

# %% [markdown]
# ### 4)  Model Building & Hyper parameter tuning

# %%
X=li.drop(['avgCompanyPosDuration'],axis=1)
y=li['avgCompanyPosDuration']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.20)

# %% [markdown]
# #### 4.1) Linear Regression

# %%
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
print('MSE is:',round(mean_squared_error(y_test,predictions),2))
print('RMSE is:',round(np.sqrt(mean_squared_error(y_test,predictions)),2))
r2 = r2_score(y_test,predictions)
print('r2 score for the model is',round(r2,2))
print('Mean Absolute Error is:',round(mean_absolute_error(y_test,predictions),2))
# Out:
# MSE is: 0.77
# RMSE is: 0.88
# r2 score for the model is 0.06
# Mean Absolute Error is: 0.58

# %%
model.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %% [markdown]
# #### 4.2) Lasso regression

# %%
from sklearn.linear_model import Lasso
l = Lasso(random_state=42)
model=l.fit( X_train, y_train )
predictions = model.predict( X_test )

# %%
from sklearn.metrics import mean_squared_error,r2_score
print('MSE is:',round(mean_squared_error(y_test,predictions),2))
print('RMSE is:',round(np.sqrt(mean_squared_error(y_test,predictions)),2))
r2 = r2_score(y_test,predictions)
print('r2 score for the model is',round(r2,2))
print('Mean Absolute Error is:',round(mean_absolute_error(y_test,predictions),2))
# Out:
# MSE is: 0.82
# RMSE is: 0.91
# r2 score for the model is 0.0
# Mean Absolute Error is: 0.61

# %% [markdown]
# ##### 4.2.1)  Lasso regression-Hyper parameter tuning

# %%
from sklearn.metrics import mean_squared_error,r2_score
def test(models, data, iterations = 100):
    results = {}
    for i in models:
        r2_train = []
        r2_test = []
        for j in range(iterations):
        
            r2_test.append(r2_score(y_test,
                                            models[i].fit(X_train, 
                                                         y_train).predict(X_test)))
            r2_train.append(r2_score(y_train, 
                                             models[i].fit(X_train, 
                                                          y_train).predict(X_train)))
        results[i] = [np.mean(r2_train), np.mean(r2_test)]
    return pd.DataFrame(results)

# %%
from sklearn.model_selection import GridSearchCV
lasso_params = {'alpha':[0.02, 0.024, 0.025, 0.026, 0.03]}

models2 = {
           'Lasso': GridSearchCV(linear_model.Lasso(), 
                               param_grid=lasso_params).fit(X_train, y_train).best_estimator_
           }

# %%
test(models2, X_test)
# Out:
#       Lasso
# 0  0.049451
# 1  0.055718

# %%
#r2 improved ,but still near to zero.

# %% [markdown]
# #### 4.3) Ridge regression

# %%
from sklearn.linear_model import Ridge
r= Ridge(random_state=42)
model=r.fit(X_train, y_train) 
predictions = model.predict( X_test )

# %%
print('MSE is:',round(mean_squared_error(y_test,predictions),2))
r2 = r2_score(y_test,predictions)
print('RMSE is:',round(np.sqrt(mean_squared_error(y_test,predictions)),2))
print('r2 score for the model is',round(r2,2))
print('Mean Absolute Error is:',round(mean_absolute_error(y_test,predictions),2))
# Out:
# MSE is: 0.77
# RMSE is: 0.88
# r2 score for the model is 0.06

# %%
model.get_params()
# Out:
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': None,
#  'normalize': 'deprecated',
#  'positive': False,
#  'random_state': 42,
#  'solver': 'auto',
#  'tol': 0.001}

# %% [markdown]
# ##### 4.3.1)  Ridge regression-Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV
model = Ridge()
# define grid
grid = dict()
grid['alpha'] =np.arange(200,800,100)
# define search
search = GridSearchCV(model, grid, n_jobs=-1)
# perform the search
results = search.fit(X, y)
predictions = results.predict( X_test )

# %%
print('MSE is:',round(mean_squared_error(y_test,predictions),2))
r2 = r2_score(y_test,predictions)
print('RMSE is:',round(np.sqrt(mean_squared_error(y_test,predictions)),2))
print('r2 score for the model is',round(r2,2))
print('Mean Absolute Error is:',round(mean_absolute_error(y_test,predictions),2))
# Out:
# MSE is: 0.77
# RMSE is: 0.88
# r2 score for the model is 0.06

# %%
#Not much improvement

# %% [markdown]
# #### 4.4) SVM Regressor

# %%
from sklearn.svm import SVR
lr=SVR(kernel='rbf')
model=lr.fit(X_train,y_train)
predictions=model.predict(X_test)   
print(y_test.head(5))
# Out:
# 37801    3.06
# 28948    1.28
# 25738    2.15
# 11477    0.25
# 15983    3.06
# Name: avgCompanyPosDuration, dtype: float64

# %%
print('MSE is:',round(mean_squared_error(y_test,predictions),2))
r2 = r2_score(y_test,predictions)
print('RMSE is:',round(np.sqrt(mean_squared_error(y_test,predictions)),2))
print('Mean Absolute Error is:',round(mean_absolute_error(y_test,predictions),2))
print('r2 score for the model is',round(r2,4))
# Out:
# MSE is: 0.82
# RMSE is: 0.9
# r2 score for the model is 0.0032

# %% [markdown]
# ##### 4.4.1)  SVM Regressor- Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.svm import SVR
# defining parameter range
param_grid = {'C': [10, 100],
              'gamma': [ 0.1, 0.01],
              'kernel': ['rbf']}
 
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
 
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.029 total time= 6.3min
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.031 total time= 7.5min
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.024 total time= 7.9min
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.021 total time= 7.8min
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.043 total time= 8.2min
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.039 total time= 8.7min
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.041 total time= 9.2min
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.031 total time= 8.3min
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.031 total time= 7.5min
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.052 total time= 8.1min
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.029 total time= 8.1min
# ...

# %%
print(grid.best_estimator_)
# Out:
# SVR(C=10, gamma=0.01)

# %%
predictions = grid.predict(X_test)

# %%
print('MSE is:',round(mean_squared_error(y_test,predictions),2))
r2 = r2_score(y_test,predictions)
print('r2 score for the model is',round(r2,2))
print('Mean Absolute Error is:',round(mean_absolute_error(y_test,predictions),2))
# Out:
# MSE is: 0.78
# r2 score for the model is 0.05
# Mean Absolute Error is: 0.58

# %% [markdown]
# #### 4.5) Random Forest regressor

# %%
from sklearn.ensemble import RandomForestRegressor
r = RandomForestRegressor(n_estimators = 100, random_state = 42)
model=r.fit(X_train,y_train)
predictions=model.predict(X_test)  
print(y_test.head(5))
# Out:
# 37801    3.06
# 28948    1.28
# 25738    2.15
# 11477    0.25
# 15983    3.06
# Name: avgCompanyPosDuration, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,r2_score
print('MSE is:',round(mean_squared_error(y_test,predictions),2))
print('RMSE is:',round(np.sqrt(mean_squared_error(y_test,predictions)),2))
print('Mean Absolute Error is:',round(mean_absolute_error(y_test,predictions),2))
r2 = r2_score(y_test,predictions)
print('r2 score for the model is',round(r2,1))
# Out:
# MSE is: 0.53
# RMSE is: 0.73
# Mean Absolute Error is: 0.37
# r2 score for the model is 0.4

# %%
model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# #####  4.5.1) Random forest regressor-Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'bootstrap': [True],
    'ccp_alpha': [0.0],
    'criterion': ['poisson'],
    'max_features':[0.75,1.0],
    'max_depth':[50,100,350],
    'min_samples_leaf':[1,2,3],
    'min_samples_split':[2,4],
    'n_estimators': [500,1000]
}
# Create a based model
rf = RandomForestRegressor(random_state = 42)
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 2, n_jobs = -1, verbose = 2)

# %%
grid_search.fit(X_train, y_train)
predictions=grid_search.predict(X_test)
# Out:
# Fitting 2 folds for each of 72 candidates, totalling 144 fits

# %%
print('MSE is:',round(mean_squared_error(y_test,predictions),2))
r2 = r2_score(y_test,predictions)
print('RMSE is:',round(np.sqrt(mean_squared_error(y_test,predictions)),2))
print('Mean Absolute Error is:',round(mean_absolute_error(y_test,predictions),2))
print('r2 score for the model is',round(r2,1))
# Out:
# MSE is: 0.52
# RMSE is: 0.72
# Mean Absolute Error is: 0.38
# r2 score for the model is 0.4

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(criterion='poisson', max_depth=100, max_features=0.75,
#                       n_estimators=1000, random_state=42)

# %% [markdown]
# #### 4.6) Extra Trees Regressor

# %%
from sklearn.ensemble import ExtraTreesRegressor
r = ExtraTreesRegressor(n_estimators = 500, random_state = 42)
model=r.fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
print('MSE is:',round(mean_squared_error(y_test,predictions),2))
r2 = r2_score(y_test,predictions)
print('RMSE is:',round(np.sqrt(mean_squared_error(y_test,predictions)),2))
print('Mean Absolute Error is:',round(mean_absolute_error(y_test,predictions),2))
print('r2 score for the model is',round(r2,2))
# Out:
# MSE is: 0.54
# RMSE is: 0.73
# Mean Absolute Error is: 0.39
# r2 score for the model is 0.34

# %% [markdown]
# #####  4.6.1) Extra Trees Regressor-Hyper parameter tuning

# %%
from sklearn.ensemble import ExtraTreesRegressor
param_grid = {
    'max_features':[0.75,1.0],
    'max_depth':[100,350],
    'min_samples_leaf':[1,2,3],
    'min_samples_split':[2,4],
    'n_estimators': [1000,2000]
}
# Create a based model
etr = ExtraTreesRegressor(random_state = 42)
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = etr, param_grid = param_grid, 
                          cv = 2, n_jobs = -1, verbose = 2)

# %%
grid_search.fit(X_train, y_train)
predictions=grid_search.predict(X_test)
# Out:
# Fitting 2 folds for each of 48 candidates, totalling 96 fits

# %%
print('MSE is:',round(mean_squared_error(y_test,predictions),2))
r2 = r2_score(y_test,predictions)
print('RMSE is:',round(np.sqrt(mean_squared_error(y_test,predictions)),2))
print('Mean Absolute Error is:',round(mean_absolute_error(y_test,predictions),2))
print('r2 score for the model is',round(r2,2))
# Out:
# MSE is: 0.54
# RMSE is: 0.74
# Mean Absolute Error is: 0.4
# r2 score for the model is 0.34

# %% [markdown]
# #### 4.6) XG Boost

# %%
import xgboost as xgb

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error,r2_score
r =xgb.XGBRegressor(n_estimators = 100, random_state = 42)
model=r.fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
print('MSE is:',round(mean_squared_error(y_test,predictions),2))
r2 = r2_score(y_test,predictions)
print('RMSE is:',round(np.sqrt(mean_squared_error(y_test,predictions)),2))
print('Mean Absolute Error is:',round(mean_absolute_error(y_test,predictions),2))
print('r2 score for the model is',round(r2,2))
# Out:
# MSE is: 0.59
# RMSE is: 0.77
# Mean Absolute Error is: 0.44
# r2 score for the model is 0.28

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error,r2_score
r =xgb.XGBRegressor(n_estimators = 1000, random_state = 42,n_jobs=-1,max_leaves= 5,learning_rate=0.1,min_child_weight=1,max_depth=10,gamma=0.02,subsample=1,reg_alpha=0,scale_pos_weight= 1)
model=r.fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
print('MSE is:',round(mean_squared_error(y_test,predictions),2))
r2 = r2_score(y_test,predictions)
print('RMSE is:',round(np.sqrt(mean_squared_error(y_test,predictions)),2))
print('Mean Absolute Error is:',round(mean_absolute_error(y_test,predictions),2))
print('r2 score for the model is',round(r2,2))
# Out:
# MSE is: 0.49
# RMSE is: 0.7
# r2 score for the model is 0.4

# %%
model.get_params()
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': 0.5,
#  'booster': 'gbtree',
#  'callbacks': None,
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'gamma': 0.02,
#  'gpu_id': -1,
#  'grow_policy': 'depthwise',
#  'importance_type': None,
#  'interaction_constraints': '',
#  'learning_rate': 0.1,
#  'max_bin': 256,
#  'max_cat_to_onehot': 4,
#  'max_delta_step': 0,
#  'max_depth': 10,
#  'max_leaves': 5,
#  'min_child_weight': 1,
#  'missing': nan,
#  'monotone_constraints': '()',
#  'n_estimators': 1000,
#  'n_jobs': -1,
#  'num_parallel_tree': 1,
#  'predictor': 'auto',
#  'random_state': 42,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'sampling_method': 'uniform',
#  'scale_pos_weight': 1,
#  'subsample': 1,
#  'tree_method': 'exact',
#  'validate_parameters': 1,
#  'verbosity': None}
